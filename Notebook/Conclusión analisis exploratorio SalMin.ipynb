# %% [markdown]
# <h2><font color="#1D4089"size=8>Conclusiones del analisis exploratorio.</font><h2>
#
# <br><br>
# <div sytle="text-align: right">
# <font color="#1D4089" size=3>Jaime Alberto Suarez Moctezuma.</font><br>
# <font color="#1D4089" size=3>Conclusiones generadas sobre el analisis exploratorio realizado de los salarios mínimos en México.</font><br>

# %% [markdown]
# <div style="text-align: justify;">
# En este análisis, se han examinado datos obtenidos de la página oficial del gobierno de México, específicamente del conjunto de datos
# <a href="https://datos.gob.mx/busca/dataset/salario-minimo-2023">Salario Mínimo 2023.</a>
# Estos datos proporcionan información valiosa sobre los salarios mínimos en diferentes zonas y ocupaciones a lo largo de varios años.
# </div>
#
# <div style="text-align: justify;">
# Este análisis nos ha permitido identificar áreas clave de interés y comprender la variabilidad en los salarios mínimos entre diferentes zonas y grupos ocupacionales. Además, hemos descubierto correlaciones significativas que indican posibles factores influyentes en los salarios mínimos.
# </div>

# %% [markdown]
# <br><font color="#1D4089" size=4>Distribución de los salarios mínimos.</font><br>

# %% [markdown]
# <div style="text-align: justify;">
#     El histograma muestra que la mayoría de los salarios mínimos se concentran en un rango específico, con algunos valores atípicos que se encuentran por encima de este rango. Esto sugiere que la mayoría de las ocupaciones tienen salarios mínimos similares, pero hay algunas excepciones que ofrecen salarios más altos.
# </div>

# %%
from IPython.display import Image

Image(filename='C:/Users/suare/Desktop/Histograma.png')

# %% [markdown]
# <p><font color="#1D4089" size=4>Evolución del salario mínimo.</font><p>

# %% [markdown]
# <div style="text-align: justify;">
#     El gráfico de líneas nos permite visualizar cómo ha evolucionado el salario mínimo general a lo largo de los años. Se observa una tendencia general de aumento en el salario mínimo a medida que avanzan los años, con algunas fluctuaciones en ciertos momentos.
# </div>

# %%
from IPython.display import Image

Image(filename="C:/Users/suare/Desktop/Grafico de barras.png")

# %% [markdown]
# <p><font color="#1D4089" size=4>Comparación de salarios mínimos por zona.</font><p>

# %% [markdown]
#  <div style="text-align: justify;">
#     La gráfica de barras compara los salarios mínimos promedio entre diferentes zonas (grupos). Se observa que existen diferencias en los salarios mínimos entre las zonas, donde algunas zonas tienen salarios mínimos más altos que otras. Esto puede estar relacionado con factores económicos y de desarrollo en cada zona.
# </div>

# %%
from IPython.display import Image

Image(filename='C:/Users/suare/Desktop/Barras.png')

# %% [markdown]
# <p><font color="#1D4089" size=4>Distribución de salarios mínimos.</font><p>

# %% [markdown]
#  <div style="text-align: justify;">El boxplot muestra la distribución de los salarios mínimos, permitiendo visualizar la mediana, los cuartiles y los valores atípicos. Se identifican algunos valores atípicos que representan ocupaciones con salarios mínimos significativamente más altos que la mediana.
# </div>

# %%
from IPython.display import Image

Image(filename='C:/Users/suare/Desktop/graficab.png')

# %% [markdown]
# <p><font color="#1D4089" size=4>Análisis de Correlación</font><p>

# %% [markdown]
# <div style="text-align: justify;">Se calculó la correlación entre el salario mínimo general y otras variables, como el año, el salario para el grupo de "chofer_camion", "boticas" y "niquelado". Se encontró una correlación positiva fuerte entre el salario mínimo general y estas variables, lo que sugiere una relación significativa entre ellos.
# </div>

# %%
from IPython.display import Image

Image(filename="C:/Users/suare/Desktop/correlaciones.png")

# %% [markdown]
# <div style="text-align: justify;">Es importante tener en cuenta que este analisis emplea datos oficiales proporcionados por el gobierno de México, lo que garantiza la fiabilidad y la relevancia de los resultados obtenidos. Sin embargo, este análisis exploratorio es solo el punto de partida para la realización de futuros modelos que permitan enteneder mejor la evolución de los salarios mínimos del país.
# </div>
